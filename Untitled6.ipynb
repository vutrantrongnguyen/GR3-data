# %% [markdown]
# <a href="https://colab.research.google.com/github/vutrantrongnguyen/GR3-data/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import zipfile
with zipfile.ZipFile('/content/GR3-get-data-main.zip', 'r') as zip_ref:
    zip_ref.extractall('/content')

# %%
# %cd GR3-get-data-main/
# %ls
# !pip install youtube_transcript_api
# !pip install pydub
# !pip install youtube-dl
# !python first-run.py
# !python main.py
# Out:
# [Errno 2] No such file or directory: 'GR3-get-data-main/'
# /content/GR3-get-data-main
# '(Among Us) Tìm kẻ phản bội cùng anh em Refund và đồng bọn.-Dm-CLGW1cn4.m4a'
# '(Among Us) Tìm kẻ phản bội cùng anh em Refund và đồng bọn.-Dm-CLGW1cn4.temp.m4a'
#  audio.py
#  auto_push.py
#  clips/
# 'Cùng Tùng Sói lắp chiếc bàn ma thuật Sisyphus trị giá nhiều chục triệu đồng.-NYDDeS6pzhE.webm.part'
#  data/
#  datacollector.py
# '(FIFA Online 4) Trận cầu siêu kinh điển Rambo vs Độ Tày với lối đá Tiki-taka Cao Bằng.-jwpjJrNYKPE.m4a'
#  first-run.py
# 'Full Livestream 15_8_2020.-ndYiEUhDQ0M.m4a.part'
#  html/
#  main.py
#  __pycache__/
#  Readme.md
#  sub.py
# '(Talkshow) Độ Mixi lần đầu được donate nguyên chiếc oto siêu xịn và Mô hình Đồ Long Đao handmade.-6yhYLvnox0w.m4a.part'
# '(Talkshow) Lên stream mặc Vest, văn hóa ứng xử của Phùng Thanh Lịch.-RXYnNO6OXSw.mp3'
# '(Talkshow) Lên stream mặc Vest, văn hóa ứng xử của Phùng Thanh Lịch.-RXYnNO6OXSw.webm'
# ...

# %%
# !python main.py
# Out:
# Khởi tạo luồng tải dữ liệu data/'list[i]'.tsv - 1 videos
# ******************0VOZRgZAaDk-0/1- Thread 0***********
# > youtube-dl -x --audio-format mp3 --audio-quality 0 https://youtube.com/watch?v=0VOZRgZAaDk
# Đang tải về audio -https://youtube.com/watch?v=0VOZRgZAaDk
# Đã tải file audio - Người sưu tầm hơn 500 thẻ cử tri _ VTV24-0VOZRgZAaDk.mp3
# temp/nguoi_suu_tam_hon_500_the_cu_tri___vtv24-0vozrgzaadk.mp3
# 100% 37/37 [00:04<00:00,  8.09it/s]

# %%
import shutil
shutil.make_archive('GR3_get_data_12', 'zip', '/content')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/lib/python3.7/zipfile.py in write(self, filename, arcname, compress_type, compresslevel)
#    1763             with open(filename, "rb") as src, self.open(zinfo, 'w') as dest:
# -> 1764                 shutil.copyfileobj(src, dest, 1024*8)
#    1765
#
# /usr/lib/python3.7/shutil.py in copyfileobj(fsrc, fdst, length)
#      81             break
# ---> 82         fdst.write(buf)
#      83
#
# /usr/lib/python3.7/zipfile.py in write(self, data)
#    1130             self._compress_size += len(data)
# -> 1131         self._fileobj.write(data)
#    1132         return nbytes
#
# OSError: [Errno 28] No space left on device
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-9be4dcc5d07c> in <module>()
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#     122   try:
# --> 123     _os.makedirs(config_dir)
#     124   except OSError:
#
# /usr/lib/python3.7/os.py in makedirs(name, mode, exist_ok)
#     222     try:
# --> 223         mkdir(name, mode)
#     224     except OSError:
#
# OSError: [Errno 28] No space left on device: '/root/.config/Google'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-d5df0069828e> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# ...

# %%
# Out:
# fatal: not a git repository (or any of the parent directories): .git
